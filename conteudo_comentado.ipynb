# %%
# LINK DE ORIGEM //// https://web3.antaq.gov.br/ea/sense/download.html#pt

import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

caminho_in = ('/content/drive/My Drive/Data/') # caminho especificio do arquivo antes de ser programado
caminho_out = ('/content/drive/My Drive/Data/') # o /data é a pasta do marquinho e o /content é o caminho dele out vai sair o caminho depois programado
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file1 = caminho_in + "2021Atracacao.txt" #O CAMINHO IN É A ORIGEM E O ATRACAO.CSV É O ARQUIVO
with open (file1, 'r', encoding='UTF-8') as f: #SOMENTE LEITURA O R É PRA ISSO
  linhas = f.readlines()
  for i in range (0, 5): #cinco primeiras linhas
    print(f"Linha {i+1}: {linhas[i]}") # escreve o noem da linha, linha é o nome e o  +1 é o nome do numero do arquivo
# Out:
# Linha 1: ﻿IDAtracacao;CDTUP;IDBerco;Berço;Porto Atracação;Coordenadas;Apelido Instalação Portuária;Complexo Portuário;Tipo da Autoridade Portuária;Data Atracação;Data Chegada;Data Desatracação;Data Início Operação;Data Término Operação;Ano;Mes;Tipo de Operação;Tipo de Navegação da Atracação;Nacionalidade do Armador;FlagMCOperacaoAtracacao;Terminal;Município;UF;SGUF;Região Geográfica;Região Hidrográfica;Instalação Portuária em Rio;Nº da Capitania;Nº do IMO
#
# Linha 2: 1203561;BRRIG;RIG2129;Carga Geral 2 PN;Rio Grande;-52.075555,-32.042499;;Rio Grande;Porto Organizado;17/11/2021 18:45:00;17/11/2021 16:10:00;18/11/2021 18:30:00;;;2021;nov;Marinha;Cabotagem;0;1;Cais comercial do Porto Novo;Rio Grande;Rio Grande do Sul;RS;Sul;;Não;;
#
# ...

# %%
df1 = pd.read_csv(file1, low_memory=False, sep=';', encoding='UTF-8', decimal=(',')) #aquivo para ler, sendo que é usado a virgula para divisao de arquvios, para não ter problemas em abrir o aquivo, separador usando ponto e vígula, e o decimal é virgula
df1.info() #.info le a barra de dados e ve todas as colunas ue tem e ve quantas colunas são não nulas (arquivo none/ ou célula vazia)


#tá rodando arquivo, só que tá rodando somente as informações

#aqui pode dar erros, pois após o id atracação se der numeros menores é porque falta arquivo, falta de dados e afins
#pode eliminar tudo que estiver em branco para não usar
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79238 entries, 0 to 79237
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   IDAtracacao                     79238 non-null  int64
#  1   CDTUP                           79238 non-null  object
#  2   IDBerco                         79107 non-null  object
#  3   Berço                           79104 non-null  object
#  4   Porto Atracação                 79107 non-null  object
#  5   Coordenadas                     79107 non-null  object
#  6   Apelido Instalação Portuária    27799 non-null  object
#  7   Complexo Portuário              79238 non-null  object
#  8   Tipo da Autoridade Portuária    79238 non-null  object
#  9   Data Atracação                  79107 non-null  object
#  10  Data Chegada                    79107 non-null  object
#  11  Data Desatracação               79238 non-null  object
# ...

# %%
file2 = caminho_in + "2022Atracacao.txt"
with open(file2, 'r', encoding='UTF-8') as f:
  linhas = f.readlines()
  for i in range (0, 5):
    print(f"Linha {i+1}: {linhas[i]}") # mesma coisa só que com a atracação  de 2022
# Out:
# Linha 1: ﻿IDAtracacao;CDTUP;IDBerco;Berço;Porto Atracação;Coordenadas;Apelido Instalação Portuária;Complexo Portuário;Tipo da Autoridade Portuária;Data Atracação;Data Chegada;Data Desatracação;Data Início Operação;Data Término Operação;Ano;Mes;Tipo de Operação;Tipo de Navegação da Atracação;Nacionalidade do Armador;FlagMCOperacaoAtracacao;Terminal;Município;UF;SGUF;Região Geográfica;Região Hidrográfica;Instalação Portuária em Rio;Nº da Capitania;Nº do IMO
#
# Linha 2: 1246116;BRREC;RECA-07;RECA-07;Recife;-34.868332,-8.053888000000001;Arrecife dos Navios;Suape - Recife;Porto Organizado;21/05/2022 13:10:00;21/05/2022 12:25:00;25/05/2022 18:10:00;;;2022;mai;Marinha;Cabotagem;0;1;Cais Público;Recife;Pernambuco;PE;Nordeste;;Não;;
#
# ...

# %%
df2 = pd.read_csv(file1, low_memory=False, sep=';', encoding='UTF-8', decimal=(','))
df2.info()

#leu os arquivos normal
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79238 entries, 0 to 79237
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   IDAtracacao                     79238 non-null  int64
#  1   CDTUP                           79238 non-null  object
#  2   IDBerco                         79107 non-null  object
#  3   Berço                           79104 non-null  object
#  4   Porto Atracação                 79107 non-null  object
#  5   Coordenadas                     79107 non-null  object
#  6   Apelido Instalação Portuária    27799 non-null  object
#  7   Complexo Portuário              79238 non-null  object
#  8   Tipo da Autoridade Portuária    79238 non-null  object
#  9   Data Atracação                  79107 non-null  object
#  10  Data Chegada                    79107 non-null  object
#  11  Data Desatracação               79238 non-null  object
# ...

# %%
csv_final = [file1, file2]
ANTAQ_Int = pd.DataFrame()
for csv_final in csv_final: ## O csv final que seria no lugar do x ele que recebe o dataframe do csv final que vem de origem o[file1,file2]
  df = pd.read_csv(csv_final, sep=';') #aqui ele recebeu separado por vrigula
  ANTAQ_Int = pd.concat([ANTAQ_Int, df], ignore_index=True) #aqui ele joga no data frame
ANTAQ_Int.info()

# PRESTA A ATENÇÃO BOCÓ AQUI QUE VEO TIPO DE AQUIVO

#coisas que não sei pq anotei
# ele pegou o o data frame (csv_final) e separou por virgula, chamou o csv final e criou ele novamente
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164330 entries, 0 to 164329
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   IDAtracacao                     164330 non-null  int64
#  1   CDTUP                           164330 non-null  object
#  2   IDBerco                         164083 non-null  object
#  3   Berço                           164080 non-null  object
#  4   Porto Atracação                 164083 non-null  object
#  5   Coordenadas                     164083 non-null  object
#  6   Apelido Instalação Portuária    57018 non-null   object
#  7   Complexo Portuário              164330 non-null  object
#  8   Tipo da Autoridade Portuária    164330 non-null  object
#  9   Data Atracação                  164083 non-null  object
#  10  Data Chegada                    164083 non-null  object
#  11  Data Desatracação               164330 non-null  object
# ...

# %%
ANTAQ_Int.head(5) #ler 5 primeiras linhas
# Out:
#    IDAtracacao  CDTUP  IDBerco             Berço Porto Atracação  \
# 0      1203561  BRRIG  RIG2129  Carga Geral 2 PN      Rio Grande
# 1      1143818  BRREC   REC-TA            REC-TA          Recife
# 2      1181323  BRMCZ  MCZ0003           Berço 3          Maceió
# 3      1135707  BRVIX  VIX0103               103         Vitória
# 4      1181313  BRMCZ  MCZ0005           Berço 5          Maceió
#
#                      Coordenadas Apelido Instalação Portuária  \
# 0          -52.075555,-32.042499                          NaN
# 1  -34.868332,-8.053888000000001          Arrecife dos Navios
# 2  -35.726388,-9.683056000000001                          NaN
# 3            -40.339444,-20.3225                          NaN
# 4  -35.726388,-9.683056000000001                          NaN
#
#   Complexo Portuário Tipo da Autoridade Portuária       Data Atracação  ...  \
# 0         Rio Grande             Porto Organizado  17/11/2021 18:45:00  ...
# ...

# %%
ANTAQ_Int.tail(5) #base/cauda ler 5 ultimas linhas
# Out:
#         IDAtracacao    CDTUP      IDBerco              Berço  \
# 164325      1392066  BRPA018  BRPA0180003  TERFRON BARCAÇA B
# 164326      1401087  BRPA018  BRPA0180003  TERFRON BARCAÇA B
# 164327      1397527  BRPA018  BRPA0180002  TERFRON BARCAÇA A
# 164328      1400372  BRPA018  BRPA0180002  TERFRON BARCAÇA A
# 164329      1358583    BRARE      ARE5005           Dolphins
#
#                                    Porto Atracação           Coordenadas  \
# 164325  Terminal Portuário Graneleiro de Barcarena        -48.727,-1.496
# 164326  Terminal Portuário Graneleiro de Barcarena        -48.727,-1.496
# 164327  Terminal Portuário Graneleiro de Barcarena        -48.727,-1.496
# 164328  Terminal Portuário Graneleiro de Barcarena        -48.727,-1.496
# 164329                                Areia Branca  -37.044722,-4.817777
#
#        Apelido Instalação Portuária     Complexo Portuário  \
# 164325                      TERFRON  Vila do Conde - Belém
# ...

# %%
colunas_interesse = ['IDAtracacao','IDBerco',
                     'Data Atracação', 'Data Chegada',
                     'Data Desatracação','Data Início Operação',
                     'Data Término Operação']  #lista
print (colunas_interesse)
# Out:
# ['IDAtracacao', 'IDBerco', 'Data Atracação', 'Data Chegada', 'Data Desatracação', 'Data Início Operação', 'Data Término Operação']

# %%
ANTAQ = ANTAQ_Int.dropna(subset=colunas_interesse)  #apaga todas as linhas vazias (NA) e somente fica as colunas de interesse
ANTAQ.info() #so vai ficar as colunas de interesse, as outras apagaram

#dropona apaga todas as linahs vazias (valores NaN)
#será removido apenas as linhas de base da colunas_interesse (subset) SELECIONOU SO AS 4 QUE EU ESCOLHI
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 156302 entries, 3 to 164329
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   IDAtracacao                     156302 non-null  int64
#  1   CDTUP                           156302 non-null  object
#  2   IDBerco                         156302 non-null  object
#  3   Berço                           156302 non-null  object
#  4   Porto Atracação                 156302 non-null  object
#  5   Coordenadas                     156302 non-null  object
#  6   Apelido Instalação Portuária    55324 non-null   object
#  7   Complexo Portuário              156302 non-null  object
#  8   Tipo da Autoridade Portuária    156302 non-null  object
#  9   Data Atracação                  156302 non-null  object
#  10  Data Chegada                    156302 non-null  object
#  11  Data Desatracação               156302 non-null  object
# ...

# %%
# Exportar o arquivo modelado em CSV.
# Se o arquivo contiver registros duplicados (mesmo navio e mesmo código),
# substituir o arquivo existente pelo novo.

# Para registros duplicados, substituir ou atualizar todas as atracações repetidas.
# Exemplo: se houver múltiplas entradas de "Soja", mas com cargas diferentes,
# é possível consolidar os dados em uma única linha, somando as quantidades
# e substituindo as linhas repetidas.

# Observação:
# A análise parou na coluna 1 após identificar os duplicados.
# Para mais detalhes, consulte o repositório do Marquino no GitHub.

# %%
duplicados = ANTAQ.duplicated(subset=['IDAtracacao'], keep=False) #duplicated é se tem valor duplicado // Keep=false signfiica que todas as linhas duplicadas serão true
if duplicados.any():
    print("Existem valores duplicados.")
    print(ANTAQ[duplicados])
else:
    print("Coluna com valores unicos.")
# Out:
# Coluna com valores unicos.

# %%
coluna = 'Complexo Portuário'
CP = ANTAQ[coluna].value_counts().sort_index()  #perguntar ao professor sobre o ANTAQ[COLUNA]
print(f"Total de operações por {coluna}:")
print(CP)
# Out:
# Total de operações por Complexo Portuário:
# Complexo Portuário
# Almeirim                                   38
# Angra dos Reis                            992
# Aracajú                                   710
# Aratu - Salvador                         3732
# Areia Branca                             4727
# Barra do Riacho                           970
# Cabedelo (Instalação Isolada)             199
# Coari (Instalação Isolada)                798
# Corumbá                                  4098
# Forno                                      12
# Ilhéus                                    391
# Imbituba                                  599
# Itaguaí                                  1978
# Itaituba                                 5616
# Itajaí                                   2086
# Itaqui                                   3981
# LDC Pederneiras (Instalação Isolada)      739
# Macapá                                    609
# Maceió                                    524
# ...
